# %% [markdown]
# # Overview
#
# This is a notebook for my personal use.
# It contains most of the modules I use for data analysis.
# Mostly of the content is only for personal reference, like: what modules to import, visualization options, and machine learning (scikit learn) options
#
# ### Index
# #### Normal (often used)
#  - NumPy
#  - Pandas
#
# #### Visualization
#  - matplotlib.pyplot
#  - seaborn
#   - *Distplot*
#   - *Joinplot*
#   - *Pointplot*
#   - *Pairplot*
#   - *KDE plot*
#   - *Rugplot*
#   - *Barplot*
#   - *Countplot*
#   - *Boxplot*
#   - *Violinplot*
#   - *Stripplot*
#   - *Swarmplot*
#   - *Catplot (factorplot)*
#   - *Heatmap*
#   - *Clustermap*
#   - *Lmplot*
#  - bokeh
#
# #### Scikit learn
#  - Linear Regression
#  - Logisitc Regression
#  - Multiclass Classification
#   - *Logistic*
#   - *K-nearest neighbor algorithm*
#  - SVM
#  - Decision Tree and Random Forest
#  - Train Test Split
#
# #### Natural Language Processing (NLTK)
#
# #### SSL issue

# %% [markdown]
# # Normal Import
#
# Often used modules:
# - **NumPy:**
#  - Documentation: https://numpy.org/devdocs/
# - **Pandas:**
#  - Documentation: https://pandas.pydata.org/pandas-docs/stable/reference/index.html

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# # Visualization Tools
#
# Often used modules:
# - **Matplotlib.pyplot:**
#  - Documentation: https://matplotlib.org/index.html
#  - **Tutorial**: https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
#  - Color Map: https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
# - **Seaborn:**
#  - Documentation: https://seaborn.pydata.org/index.html
#  - Color Palettes: https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# display
# %matplotlib inline

# set style
sns.set_style('whitegrid')

# %%
# sample data
# tips
tips = sns.load_dataset('tips')
tips

# flights
flights = sns.load_dataset("flights")

# %% [markdown]
# ## - Seaborn

# %% [markdown]
# ### Distplot :
# Histogram + KDE line

# %%
sns.distplot(tips['total_bill'], bins=30)

# %%
# KDE disabled
sns.distplot(tips['total_bill'], bins=30, kde=False)

# %% [markdown]
# ### Joinplot :
# two kinds of plot into one <br>
# Options(kind): scatter、reg、resid、kde、hex

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# ### Pointplot

# %%
sns.pointplot(x="day",y="tip",data=tips)

# %% [markdown]
# ### Pairplot
# compairing variables against variables

# %%
sns.pairplot(tips)

# %% [markdown]
# Using pairplot with hue and palette

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# ### KDE plot
# KDE means **Kernel Density Estimation**

# %%
sns.kdeplot(tips['total_bill'])

# %% [markdown]
# ### Rugplot

# %%
sns.rugplot(tips['tip'])

# %% [markdown]
# ### Barplot

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)

# %% [markdown]
# ### Countplot
# frequency of certain values occour

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ### Boxplot
# shows 0, 25, 50, 75, 100 percentile
# (also good at displaying outliers)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %% [markdown]
# ### Violinplot
# Boxplot + the ability to show density

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %% [markdown]
# ### Stripplot

# %%
# use jitter=True to avoid overlaying
# use dodge=True to seperate different hue
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',dodge=True)

# %% [markdown]
# ### Swarmplot
# Violinplot + Swarmplot

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %% [markdown]
# ### Catplot (factorplot)
# Use **kind** to define what kind of plot you want. <br>
# Options are: **“point”, “bar”, “strip”, “swarm”, “box”, “violin”,** or **“boxen”.**

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# %% [markdown]
# ### Heatmap

# %%
# Corelation - corr()
tc = tips.corr()
# use annot=True to display value
sns.heatmap(tc, annot=True, cmap='coolwarm')

# %%
# pivot table
fp = flights.pivot_table(index='month',columns='year',values='passengers')

sns.heatmap(fp,cmap='magma',linecolor='white',linewidths=1)

# %% [markdown]
# ### Clustermap
# Heatmap + **Hierarchical Clustering**

# %%
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# ### lmplot
# fit regression models across conditional subsets of a dataset.

# %%
# lmplot(x,y,data)
# use marker + hue to seperate different kind of data
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':100})

# %%
# use col for 3rd feature(variable)
# use row for 4th feature(variable)
# aspect = ratio(hight:width)
# height = size
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex', row='time', aspect=1, height=4)

# %% [markdown]
# ## - Matplotlib.pyplot.plot (plt.plot)
# create simple plot

# %%
tips.tip.plot(bins=100, kind='hist')

# %%
plt.plot(tips.tip, tips.total_bill, marker='o', linestyle='', color='b', alpha=0.3)

# %%
from collections import Counter
# Counter(tips.sex).keys() # equals to list(set(words))
# Counter(tips.sex).values() # counts the elements' frequency

plt.bar(Counter(tips.sex).keys(),Counter(tips.sex).values())
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# other visualization module:
# - **Bokeh (interactive)**
#  - Documentation: https://docs.bokeh.org/en/latest/index.html

# %% [markdown]
# # Machine Learning, ML
#
# Often used module:
#
# - **Scikit Learn:**
#  - Documentation: https://scikit-learn.org/stable/modules/classes.html

# %% [markdown]
# ## - Linear Regression

# %%
# import Linear Regression Module
from sklearn.linear_model import LinearRegression

# seperate your features(X) and target(Y)

# make a object of this function
lreg = LinearRegression()

# fit the model
lreg.fit(X,Y)

# you can see how the model looks like using these two lines
print("The estimated intercept coefficient is %.2f" %lreg.intercept_)
print("The number of coefficient used was %d" %len(lreg.coef_))

# check out the coefficients
# make a dataframe of features and their coefficient
coeff_df = DataFrame(features.columns)
# Naming the columns
coeff_df.columns = ['Features']
# and put the values in to the columns
coeff_df['Coefficient Estimate'] = Series(lreg.coef_)
coeff_df

# %% [markdown]
# ## - Logistic Regression (Classification)

# %%
# import
from sklearn.linear_model import LogisticRegression

# Learn
# make a object of this function
log_model = LogisticRegression()
# fit the model
log_model.fit(X,Y)

# Rate accuracy of the model
accuracy_score = log_model.score(X,Y) 

# Get the coefficient of this model
# make a dataframe of features and their coefficient
coeff_df = DataFrame(zip(X.columns, np.transpose(log_model.coef_)))
# naming the columns
coeff_df.columns = ['Variables','Coefficient']
# show
coeff_df

# Intepretation: 
# Positive numbers mean they "increase the likelyhood" of causing target "y=1" to happen
# Note that all the rest of the occupation are positive(+) number, 
# this mean the occupation that we droped (student), has the lowest likelyhood (closed to baseline)

# %% [markdown]
# ## - Multiclass Classification

# %% [markdown]
# ### LogisticRegression

# %%
# import
from sklearn.linear_model import LogisticRegression

# make a object of this function
LogReg = LogisticRegression()
# fit the model
LogReg.fit(X,Y)

# test the accuracy of the model using testing data
from sklearn import metrics
Y_pred = LogReg.predict(x_test)
# result
metrics.accuracy_score(y_test, Y_pred)

# %% [markdown]
# ### K-nearest neighbor algorithm
# the main drop back of this method is the complexity of searching the neareset neighbor in each class

# %%
# import
from sklearn.neighbors import KNeighborsClassifier

# make a object of this function
# pass in "K (a.k.a numbers of neightbors)" value, try out different values
# value of "K" "MUST NOT" be even numbers(e.g. 2,4,6,...) and the multiply of the number of classes (n * anynumber)
knn = KNeighborsClassifier(n_neighbors = 1)
# fit the model
knn.fit(x_train, y_train)

# test the accuracy of the model using testing data
knn_y_pred = knn.predict(x_test)
from sklearn import metrics
knn_y_pred = knn.predict(x_test)
# result
metrics.accuracy_score(y_test, knn_y_pred)

# %% [markdown]
# Try out different value K using:

# %%
# set up a list of number K
K_range = range(1,21)
# empty list to test the accuracy
accuracy = []

for k in K_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(x_train, y_train)
    knn_y_pred = knn.predict(x_test)
    
    accuracy.append(metrics.accuracy_score(y_test, knn_y_pred))

# print result
accuracy

# or plot it
plt.plot(K_range, accuracy)
plt.xlabel('K Value')
plt.ylabel('Testing Accuracy')

# %% [markdown]
# ## - Support Vector Machines, SVM
# mainly used to find non-linear classes
#
#
# ### C-Support Vector Classification:

# %%
# import
from sklearn.svm import SVC

# make a object of this function
# where C being the Regularization Parameter
model = SVC(C=2)
# fit the data to the model
model.fit(x_train, y_train)

# test the accuracy
from sklearn import metrics
# predicted value
predicted = model.predict(x_test)
# expected value
expected = y_test
# get result
print(metrics.accuracy_score(expected, predicted))

# %% [markdown]
# ### Other Support Vector Machines (SVM)
#
# **Kernel:**
# - Linear Kernel - SVC(kernel='linear')
# - RBF Kernel - SVC(kernel='rbf') # default
# - Polynomial Kernel - SVC(kernel='poly')
#
# **Linear:**
# - LinearSVC()
#
# * difference between **LinearSVC()** and **SVC(kernel='linear')** *: <br>
# https://stackoverflow.com/questions/45384185/what-is-the-difference-between-linearsvc-and-svckernel-linear/45390526

# %%
# import
from sklearn import svm

# set up C value
C_svm = 1.0

# Make a object of this function
# linear (One-vs-one)
svc = svm.SVC(kernel='linear',C=C_svm).fit(X_svm,Y_svm)

# rbf (need to set gamma value)
rbf_svc = svm.SVC(kernel='rbf', C=C_svm, gamma=0.7).fit(X_svm, Y_svm)

# polynomial Model (need to set up degree of function)
poly_svc = svm.SVC(kernel='poly', C=C_svm, degree=3).fit(X_svm, Y_svm)

# linear (One-vs-all)
lin_svc = svm.LinearSVC(C=C_svm).fit(X_svm, Y_svm)

# %%
# Meshgrid
# set the step size
h = 0.02

# X axis min and max (first feature)
x_min=X[:, 0].min() - 1
x_max =X[:, 0].max() + 1

# Y axis min and max (first feature)
y_min = X[:, 1].min() - 1
y_max = X[:, 1].max() + 1

# Finally, numpy can create a meshgrid
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))

# %%
# Plotting
# Set up plot title
titles = ['SVC with linear kernel',
          'LinearSVC (linear kernel)',
          'SVC with RBF kernel',
          'SVC with polynomial (degree 3) kernel']

# plot function
for i, clf in enumerate((svc, lin_svc, rbf_svc, poly_svc)):
    
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    plt.figure(figsize=(15,15))
    
    # Set the subplot position (Size = 2 by 2, position deifined by i count
    plt.subplot(2, 2, i + 1)
    
    # Subplot spacing
    # SPACING - wspace: width(horizontal), hspace: height(vertical)
    plt.subplots_adjust(wspace=0.4, hspace=0.4)
    
    # Define Z as the prediction, not the use of ravel to format the arrays
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    
    # Contour plot (filled with contourf)
    plt.contourf(xx, yy, Z, cmap=plt.cm.terrain, alpha=0.5,linewidths=0)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Dark2)
    
    # Labels and Titles
    plt.xlabel('Feature 1 (X1)')
    plt.ylabel('Feature 2 (X2)')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(titles[i])

# %% [markdown]
# ## Decision Trees and Random Forests

# %%
# import
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# mashgrid (to plot out the decision boundary)

def visualize_tree(classifier, X, y, boundaries=True,xlim=None, ylim=None):
    '''
    Visualizes a Decision Tree. 
    INPUTS: Classifier Model, X, y, optional x/y limits.
    OUTPUTS: Meshgrid visualization for boundaries of the Decision Tree
    '''
     
    # Fit the X and y data to the tree
    classifier.fit(X, y)

    
    # Automatically set the x and y limits to the data (+/- 0.1)
    if xlim is None:
        xlim = (X[:, 0].min() - 0.1, X[:, 0].max() + 0.1)
    if ylim is None:
        ylim = (X[:, 1].min() - 0.1, X[:, 1].max() + 0.1)

    # Assign the variables
    x_min, x_max = xlim
    y_min, y_max = ylim
    
    
    # Create a mesh grid
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))
    
    # Define the Z by the predictions (this will color in the mesh grid)
    Z = classifier.predict(np.c_[xx.ravel(), yy.ravel()])

    # Reshape based on meshgrid
    Z = Z.reshape(xx.shape)
    
    # Plot the figure (use)
    plt.figure(figsize=(10,10))
    plt.pcolormesh(xx, yy, Z, alpha=0.2, cmap='jet')
    

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='jet')
    
    #Set Limits
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)        
    
    def plot_boundaries(i, xlim, ylim):
        '''
        Plots the Decision Boundaries
        '''
        if i < 0:
            return

        # Shorter variable name
        tree = classifier.tree_
        
        # Recursively go through nodes of tree to plot boundaries.
        if tree.feature[i] == 0:
            plt.plot([tree.threshold[i], tree.threshold[i]], ylim, '-k')
            plot_boundaries(tree.children_left[i],
                            [xlim[0], tree.threshold[i]], ylim)
            plot_boundaries(tree.children_right[i],
                            [tree.threshold[i], xlim[1]], ylim)
        
        elif tree.feature[i] == 1:
            plt.plot(xlim, [tree.threshold[i], tree.threshold[i]], '-k')
            plot_boundaries(tree.children_left[i], xlim,
                            [ylim[0], tree.threshold[i]])
            plot_boundaries(tree.children_right[i], xlim,
                            [tree.threshold[i], ylim[1]])
    
    # Random Forest vs Single Tree
    if boundaries:
        plot_boundaries(0, plt.xlim(), plt.ylim())

# %%
# Make a object of this function
Decision_Tree_clf = DecisionTreeClassifier(max_depth=2, random_state=0)

# Plot
visualize_tree(Decision_Tree_clf,X,y)

# %%
# Make a object of this function

# n_estimators --> how many trees, 100-400 trees are usually enough
Random_Forest_clf = RandomForestClassifier(n_estimators=100, random_state=0)
# Since ensemble means you can calculate trees independently, 
# you can put them on different computer/server to calculate, and then you can put them together

# Plot
visualize_tree(Random_Forest_clf, X, y, boundaries=False)

# %%
# import
from sklearn.ensemble import RandomForestRegressor

# Make a object of this function
# not just a classification, but also a powerful regression technique

# Make a object of this function
rfr = RandomForestRegressor(100)

rfr.fit(x_train, y_train)
predicted = rfr.predict(x_test)
expected = y_test

# %%
# Plot
plt.figure(figsize=(15,8))
plt.errorbar(X,Y,0.1,fmt='o')
plt.plot(x_train, y_train, '-r')
plt.plot(x_train, y_test, '-k', alpha=0.5)

# %% [markdown]
# # Train Test Split
# split your data randomly to get **training set** and **testing set**

# %%
# import
from sklearn.model_selection import train_test_split

# split
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# fit model with training set (assuming correct model is imported already)
model.fit(x_train, y_train)

# validate (the accuracy of) your model using the testing set
from sklearn import metrics

# predicted value
predicted = model.predict(x_test)

# expected value
expected = y_test

# get result
print(metrics.accuracy_score(expected, predicted))

# %% [markdown]
# # NLTK (Natural Language Processing)
#
# NLTK Documentation: http://www.nltk.org/book/

# %%
import nltk

# %%
# Get data
nltk.download()

# %% [markdown]
# # SSL issue
# Sometime it shows some SSL error, use this method

# %%
# import ssl to bypass the SSL certificate problem
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
